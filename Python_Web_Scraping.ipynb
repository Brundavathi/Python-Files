# %% [markdown]
# <a href="https://colab.research.google.com/github/Brundavathi/Python-Files/blob/main/Python_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Request a webpage

import requests

# %%
data = requests.get("https://perceptrons.ai")

# %%
html = data.content

# %%
print(html)
# Out:
# b'<!DOCTYPE html> \n<html itemscope itemtype="http://schema.org/WebPage" lang="en-US">\n<head>\n\t<!-- Required meta tags -->\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\t<meta name="description" content="Learn Data Science, Artificial Intelligence, Big Data Analytics and Tableau. We provide data science classroom and live online training courses.">\n\t<meta name="keywords" content="Data Science Training in Bangalore, Data Science Training in Bengaluru, Data Science Course in Bangalore, Data Scientist Training in Bangalore, Data Science with Python Training in Bangalore, Machine Learning Course in Bangalore, Machine learning Python Training,machine learning tutorials python, Statistics for Data Science, Data Science Classroom Training, ONLINE Training, How to Become Data Scientist, How to Learn Data Science, Tableau Training, Artificial Intelligence Training in Bangalore, AI training in Bangalore, AI coaching i
# ...

# %%
import bs4

# %%
res = requests.get("https://perceptrons.ai")

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!DOCTYPE html> \n<html itemscope itemtype="http://schema.org/WebPage" lang="en-US">\n<head>\n\t<!-- Required meta tags -->\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n\t<meta name="description" content="Learn Data Science, Artificial Intelligence, Big Data Analytics and Tableau. We provide data science classroom and live online training courses.">\n\t<meta name="keywords" content="Data Science Training in Bangalore, Data Science Training in Bengaluru, Data Science Course in Bangalore, Data Scientist Training in Bangalore, Data Science with Python Training in Bangalore, Machine Learning Course in Bangalore, Machine learning Python Training,machine learning tutorials python, Statistics for Data Science, Data Science Classroom Training, ONLINE Training, How to Become Data Scientist, How to Learn Data Science, Tableau Training, Artificial Intelligence Training in Bangalore, AI training in Bangalore, AI coaching in
# ...

# %%
#Parse and Extract Data

soup = bs4.BeautifulSoup(res.text,'html')

# %%
headings = soup('h1')
headings
# Out:
# [<h1>Certified <br/> Data Scientist</h1>,
#  <h1>Artificial Intelligence<br/> Specialization</h1>,
#  <h1>Big Data<br/>Certification</h1>,
#  <h1>Computer Vision Specialization</h1>,
#  <h1>Tableau Certification Training</h1>,
#  <h1>NLP and Chatbots Specialization</h1>,
#  <h1>Register for a free demo class</h1>]

# %%
headings[0]
# Out:
# <h1>Certified <br/> Data Scientist</h1>

# %%
headings[0].getText() # Removed h1 tags
# Out:
# 'Certified  Data Scientist'

# %%
type(headings)
# Out:
# bs4.element.ResultSet

# %%
soup.find_all('h1')
# Out:
# [<h1>Certified <br/> Data Scientist</h1>,
#  <h1>Artificial Intelligence<br/> Specialization</h1>,
#  <h1>Big Data<br/>Certification</h1>,
#  <h1>Computer Vision Specialization</h1>,
#  <h1>Tableau Certification Training</h1>,
#  <h1>NLP and Chatbots Specialization</h1>,
#  <h1>Register for a free demo class</h1>]

# %%
all_price = soup('span')
all_price
# Out:
# [<span class="lnr lnr-phone"></span>, <span class="text">
#  <span class="text">082 9600 6295 | 080 7963 4987</span>
#  </span>, <span class="text">082 9600 6295 | 080 7963 4987</span>, <span class="lnr lnr-envelope"></span>, <span class="text">
#  <span class="text">hi@perceptrons.ai</span>
# ...

# %%
for i in soup.select("view_details"):
  print(i)

# %%
abc = soup.find_all("span",{"class" : "view_details"}) 
abc  #[0]   #.getText()
# Out:
# [<span class="view_details"><a href="certified-data-scientist-training-course"> Explore Program <span class="lnr lnr-arrow-right"></span></a></span>,
#  <span class="view_details"><a href="artificial-intelligence-specialization-certification-training-course"> Explore Program <span class="lnr lnr-arrow-right"></span></a></span>,
#  <span class="view_details"><a href="big-data-certification-training-bangalore"> Explore Program <span class="lnr lnr-arrow-right"></span></a></span>,
#  <span class="view_details"><a href="computer-vision-specialization-training-course"> Explore Program <span class="lnr lnr-arrow-right"></span></a></span>,
#  <span class="view_details"><a href="tableau-certification-training-course"> Explore Program <span class="lnr lnr-arrow-right"></span></a></span>,
#  <span class="view_details"><a href="nlp-chatbots-specialization-training-course">Explore Program <span class="lnr lnr-arrow-right"></span></a></span>]
